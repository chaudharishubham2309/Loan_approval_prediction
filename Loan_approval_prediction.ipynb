# %%
## Install the libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %%
df=pd.read_csv('/content/Dataset.csv')
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df.shape
# Out:
# (614, 13)

# %%
df.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
df.head(10)
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
# 5  LP001011   Male     Yes          2      Graduate           Yes
# 6  LP001013   Male     Yes          0  Not Graduate            No
# 7  LP001014   Male     Yes         3+      Graduate            No
# 8  LP001018   Male     Yes          2      Graduate            No
# 9  LP001020   Male     Yes          1      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# ...

# %%
df.tail(10)
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 604  LP002959  Female     Yes          1      Graduate            No
# 605  LP002960    Male     Yes          0  Not Graduate            No
# 606  LP002961    Male     Yes          1      Graduate            No
# 607  LP002964    Male     Yes          2  Not Graduate            No
# 608  LP002974    Male     Yes          0      Graduate            No
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 604            12000                0.0       496.0             360.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
plt.figure(figsize=(12,12))
sns.boxplot(data=df)
# Out:
# <Axes: >

# %%
#As outiliers are present in the applicantincome is more and applicant income is an numerical atrribute and more attribute are present so we will replaace
## Fill the null values of numerical datatype
df['LoanAmount'] = df['LoanAmount'].fillna(df['LoanAmount'].median())
df['Loan_Amount_Term'] = df['Loan_Amount_Term'].fillna(df['Loan_Amount_Term'].mean())
df['Credit_History'] = df['Credit_History'].fillna(df['Credit_History'].mean())

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            0
# Loan_Amount_Term      0
# Credit_History        0
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
## Fill the null values of object datatype
df['Gender'] = df['Gender'].fillna(df['Gender'].mode()[0])
df['Married'] = df['Married'].fillna(df['Married'].mode()[0])
df['Dependents'] = df['Dependents'].fillna(df['Dependents'].mode()[0])

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender                0
# Married               0
# Dependents            0
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            0
# Loan_Amount_Term      0
# Credit_History        0
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
df.info('Self_Employed')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             614 non-null    object
#  2   Married            614 non-null    object
#  3   Dependents         614 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         614 non-null    float64
#  9   Loan_Amount_Term   614 non-null    float64
#  10  Credit_History     614 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
df['Self_Employed'] = df['Self_Employed'].fillna(df['Self_Employed'].mode()[0])

# %%
df.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
print('Number of people who took loan by gender')
print(df['Gender'].value_counts())
sns.countplot(x='Gender',data = df, palette='Set1')
# Out:
# Number of people who took loan by gender
# Gender
# Male      502
# Female    112
# Name: count, dtype: int64
# <Axes: xlabel='Gender', ylabel='count'>

# %%
print('Number of people who took loan by Married')
print(df['Married'].value_counts())
sns.countplot(x='Married',data = df, palette='Set1')
# Out:
# Number of people who took loan by Married
# Married
# Yes    401
# No     213
# Name: count, dtype: int64
# <Axes: xlabel='Married', ylabel='count'>

# %%
print('Number of people who took loan by Education')
print(df['Education'].value_counts())
sns.countplot(x='Education',data = df, palette='Set1')
# Out:
# Number of people who took loan by Education
# Education
# Graduate        480
# Not Graduate    134
# Name: count, dtype: int64
# <Axes: xlabel='Education', ylabel='count'>

# %%
corr = df.corr()
plt.figure(figsize=(10,8))
sns.heatmap(corr,annot = True, cmap = 'BuPu')
# Out:
# <Axes: >

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             614 non-null    object
#  2   Married            614 non-null    object
#  3   Dependents         614 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      614 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         614 non-null    float64
#  9   Loan_Amount_Term   614 non-null    float64
#  10  Credit_History     614 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
df.select_dtypes(include='object').columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
df['Loan_ID'] = pd.to_numeric(df['Loan_ID'], errors='coerce')

# %%
corr = df.corr()
plt.figure(figsize=(10,8))
sns.heatmap(corr,annot = True, cmap = 'BuPu')
# Out:
# <Axes: >

# %%
# Import label encoder
from sklearn import preprocessing

# label_encoder object knows how
# to understand word labels.
label_encoder = preprocessing.LabelEncoder()
obj = (df.dtypes == 'object')
for col in list(obj[obj].index):
 df[col] = label_encoder.fit_transform(df[col])

# %%
corr = df.corr()
plt.figure(figsize=(10,8))
sns.heatmap(corr,annot = True, cmap = 'BuPu')
# Out:
# <Axes: >

# %%
corr = df.corr()
corr
# Out:
#                    Loan_ID    Gender   Married  Dependents  Education  \
# Loan_ID                NaN       NaN       NaN         NaN        NaN
# Gender                 NaN  1.000000  0.364569    0.172914   0.045364
# Married                NaN  0.364569  1.000000    0.334216   0.012304
# Dependents             NaN  0.172914  0.334216    1.000000   0.055752
# Education              NaN  0.045364  0.012304    0.055752   1.000000
# Self_Employed          NaN -0.000525  0.004489    0.056798  -0.010383
# ApplicantIncome        NaN  0.058809  0.051708    0.118202  -0.140760
# CoapplicantIncome      NaN  0.082912  0.075948    0.030430  -0.062290
# LoanAmount             NaN  0.106904  0.146546    0.163103  -0.168759
# Loan_Amount_Term       NaN -0.073567 -0.100863   -0.101054  -0.077242
# Credit_History         NaN  0.012819  0.005852   -0.037392  -0.077936
# Property_Area          NaN -0.025752  0.004257   -0.000244  -0.065243
# ...

# %%
## Total Applicant Income

df['Total_Income'] = df['ApplicantIncome'] + df['CoapplicantIncome']
df.head()
# Out:
#    Loan_ID  Gender  Married  Dependents  Education  Self_Employed  \
# 0      NaN       1        0           0          0              0
# 1      NaN       1        1           1          0              0
# 2      NaN       1        1           0          0              1
# 3      NaN       1        1           0          1              0
# 4      NaN       1        0           0          0              0
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0       128.0             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History  Property_Area  Loan_Status  Total_Income
# 0             1.0              2            1        5849.0
# ...

# %%
## Apply Log Transformation

df['ApplicantIncomelog'] = np.log(df['ApplicantIncome'] + 1)
sns.distplot(df['ApplicantIncomelog'])
# Out:
# <Axes: xlabel='ApplicantIncomelog', ylabel='Density'>

# %%
df.head()
# Out:
#    Loan_ID  Gender  Married  Dependents  Education  Self_Employed  \
# 0      NaN       1        0           0          0              0
# 1      NaN       1        1           1          0              0
# 2      NaN       1        1           0          0              1
# 3      NaN       1        1           0          1              0
# 4      NaN       1        0           0          0              0
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0       128.0             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History  Property_Area  Loan_Status  Total_Income  \
# 0             1.0              2            1        5849.0
# ...

# %%
df['LoanAmountlog'] = np.log(df['LoanAmount'] + 1)
sns.distplot(df['LoanAmountlog'])
# Out:
# <Axes: xlabel='LoanAmountlog', ylabel='Density'>

# %%
import numpy as np
import seaborn as sns

try:
    # Check if 'Loan_Amount_Term' exists in the DataFrame
    if 'Loan_Amount_Term' in df.columns:
        # Perform the log transformation
        df['Loan_Amount_Term_log'] = np.log(df['Loan_Amount_Term'] + 1)

        # Plot the distribution of the transformed data
        sns.distplot(df['Loan_Amount_Term_log'])
    else:
        print("Error: 'Loan_Amount_Term' column does not exist in the DataFrame.")
except Exception as e:
    print("An error occurred:", e)

# %%
df['Total_Income_log'] = np.log(df['Total_Income'] + 1)
sns.distplot(df['Total_Income_log'])
# Out:
# <Axes: xlabel='Total_Income_log', ylabel='Density'>

# %%
df.head()
# Out:
#    Loan_ID  Gender  Married  Dependents  Education  Self_Employed  \
# 0      NaN       1        0           0          0              0
# 1      NaN       1        1           1          0              0
# 2      NaN       1        1           0          0              1
# 3      NaN       1        1           0          1              0
# 4      NaN       1        0           0          0              0
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0       128.0             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History  Property_Area  Loan_Status  Total_Income  \
# 0             1.0              2            1        5849.0
# ...

# %%
## drop unnecessary columns
cols = ['ApplicantIncome','CoapplicantIncome','LoanAmount','Loan_Amount_Term','Total_Income','Loan_ID']
df = df.drop(columns = cols, axis = 1)
df.head()
# Out:
#    Gender  Married  Dependents  Education  Self_Employed  Credit_History  \
# 0       1        0           0          0              0             1.0
# 1       1        1           1          0              0             1.0
# 2       1        1           0          0              1             1.0
# 3       1        1           0          1              0             1.0
# 4       1        0           0          0              0             1.0
#
#    Property_Area  Loan_Status  ApplicantIncomelog  LoanAmountlog  \
# 0              2            1            8.674197       4.859812
# 1              0            0            8.430327       4.859812
# 2              2            1            8.006701       4.204693
# 3              2            1            7.857094       4.795791
# 4              2            1            8.699681       4.955827
#
#    Loan_Amount_Term_log  Total_Income_log
# 0              5.888878          8.674197
# 1              5.888878          8.714732
# ...

# %%
## Encoding Technique : Label Encoding, One Hot Encoding

from sklearn.preprocessing import LabelEncoder
cols = ['Gender','Married','Education','Dependents','Self_Employed','Property_Area','Loan_Status']
le =  LabelEncoder()
for col in cols:
  df[col] =  le.fit_transform(df[col])

# %%
df.head()
# Out:
#    Gender  Married  Dependents  Education  Self_Employed  Credit_History  \
# 0       1        0           0          0              0             1.0
# 1       1        1           1          0              0             1.0
# 2       1        1           0          0              1             1.0
# 3       1        1           0          1              0             1.0
# 4       1        0           0          0              0             1.0
#
#    Property_Area  Loan_Status  ApplicantIncomelog  LoanAmountlog  \
# 0              2            1            8.674197       4.859812
# 1              0            0            8.430327       4.859812
# 2              2            1            8.006701       4.204693
# 3              2            1            7.857094       4.795791
# 4              2            1            8.699681       4.955827
#
#    Loan_Amount_Term_log  Total_Income_log
# 0              5.888878          8.674197
# 1              5.888878          8.714732
# ...

# %%
df.dtypes
# Out:
# Gender                    int64
# Married                   int64
# Dependents                int64
# Education                 int64
# Self_Employed             int64
# Credit_History          float64
# Property_Area             int64
# Loan_Status               int64
# ApplicantIncomelog      float64
# LoanAmountlog           float64
# Loan_Amount_Term_log    float64
# Total_Income_log        float64
# dtype: object

# %%
## Split Independent and dependent features

X = df.drop(columns = ['Loan_Status'],axis = 1)
y = df['Loan_Status']

# %%
X
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  Credit_History  \
# 0         1        0           0          0              0             1.0
# 1         1        1           1          0              0             1.0
# 2         1        1           0          0              1             1.0
# 3         1        1           0          1              0             1.0
# 4         1        0           0          0              0             1.0
# ..      ...      ...         ...        ...            ...             ...
# 609       0        0           0          0              0             1.0
# 610       1        1           3          0              0             1.0
# 611       1        1           1          0              0             1.0
# 612       1        1           2          0              0             1.0
# 613       0        0           0          0              1             0.0
#
# ...

# %%
y
# Out:
# 0      1
# 1      0
# 2      1
# 3      1
# 4      1
#       ..
# 609    1
# 610    1
# 611    1
# 612    1
# 613    0
# Name: Loan_Status, Length: 614, dtype: int64

# %%
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.25,random_state = 42)

# %%
## Logistic Regression
model1 = LogisticRegression()
model1.fit(X_train,y_train)
y_pred_model1 = model1.predict(X_test)
accuracy = accuracy_score(y_test,y_pred_model1)

# %%
accuracy*100
## Accuracy : the ratio of the correctly predicted values to total values
# Out:
# 77.27272727272727

# %%
score = cross_val_score(model1,X,y,cv=5)
score
# Out:
# array([0.81300813, 0.7804878 , 0.7804878 , 0.85365854, 0.81967213])

# %%
np.mean(score)*100
# Out:
# 80.9462881514061

# %%
## Decision Tree Classifier

model2 = DecisionTreeClassifier()
model2.fit(X_train,y_train)
y_pred_model2 = model2.predict(X_test)
accuracy = accuracy_score(y_test,y_pred_model2)
print("Accuracy score of Decision Tree: ", accuracy*100)
# Out:
# Accuracy score of Decision Tree:  72.07792207792207

# %%
score = cross_val_score(model2,X,y,cv=5)
print("Cross Validation score of Decision Tree: ",np.mean(score)*100)
# Out:
# Cross Validation score of Decision Tree:  70.03598560575769

# %%
## Random Forest Classifier
model3 = RandomForestClassifier()
model3.fit(X_train,y_train)
y_pred_model3 = model3.predict(X_test)
accuracy = accuracy_score(y_test,y_pred_model3)
print("Accuracy score of Random Forest: ", accuracy*100)
# Out:
# Accuracy score of Random Forest:  77.92207792207793

# %%
#KNearestNeighbors model
model4 = KNeighborsClassifier(n_neighbors=3)
model4.fit(X_train,y_train)
y_pred_model4 = model4.predict(X_test)
accuracy = accuracy_score(y_test,y_pred_model4)
print("Accuracy score of KNeighbors: ", accuracy*100)
# Out:
# Accuracy score of KNeighbors:  71.42857142857143

# %%
from sklearn.metrics import classification_report

def generate_classification_report(model_name,y_test,y_pred):
  report = classification_report(y_test,y_pred)
  print(f"Classification Report For {model_name}:\n{report}\n")

generate_classification_report(model1,y_test,y_pred_model1)
generate_classification_report(model2,y_test,y_pred_model2)
generate_classification_report(model3,y_test,y_pred_model3)
generate_classification_report(model4,y_test,y_pred_model4)
# Out:
# Classification Report For LogisticRegression():
#               precision    recall  f1-score   support
#
#            0       0.91      0.39      0.55        54
#            1       0.75      0.98      0.85       100
#
#     accuracy                           0.77       154
#    macro avg       0.83      0.68      0.70       154
# weighted avg       0.81      0.77      0.74       154
#
#
# Classification Report For DecisionTreeClassifier():
#               precision    recall  f1-score   support
#
#            0       0.62      0.54      0.57        54
#            1       0.77      0.82      0.79       100
#
#     accuracy                           0.72       154
#    macro avg       0.69      0.68      0.68       154
# weighted avg       0.71      0.72      0.72       154
#
#
# Classification Report For RandomForestClassifier():
#               precision    recall  f1-score   support
#
#            0       0.83      0.46      0.60        54
# ...

# %%
df['Loan_Status'].value_counts()
# Out:
# Loan_Status
# 1    422
# 0    192
# Name: count, dtype: int64

# %%
pip install -U imbalanced-learn
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 258.0/258.0 kB 3.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: imbalanced-learn
#     Found existing installation: imbalanced-learn 0.10.1
#     Uninstalling imbalanced-learn-0.10.1:
#       Successfully uninstalled imbalanced-learn-0.10.1
# ...

# %%
from sklearn.linear_model import LogisticRegression
import numpy as np

# Training data (X_train, y_train) should be available before running this code

# Train a logistic regression model
model = LogisticRegression()
model.fit(X_train, y_train)

# Now, let's manually enter input for prediction
print("Please enter the following details:")
gender = int(input("Gender (1 for Male, 0 for Female): "))
married = int(input("Married (1 for Yes, 0 for No): "))
dependents = int(input("Dependents: "))
education = int(input("Education (1 for Graduate, 0 for Not Graduate): "))
self_employed = int(input("Self Employed (1 for Yes, 0 for No): "))
credit_history = float(input("Credit History (e.g., 1.0): "))
property_area = int(input("Property Area (0 for Urban, 1 for Rural, 2 for Semiurban): "))
applicant_income_log = float(input("Applicant Income log: "))
loan_amount_log = float(input("Loan Amount log: "))
loan_amount_term_log = float(input("Loan Amount Term log: "))
total_income_log = float(input("Total Income log: "))

# Create a numpy array with the input data
new_data = np.array([[gender, married, dependents, education, self_employed,
                      credit_history, property_area, applicant_income_log,
                      loan_amount_log, loan_amount_term_log, total_income_log]])

# Use the trained model to predict
prediction = model.predict(new_data)

if prediction[0] == 1:
    print("Loan will be approved")
else:
    print("Loan will not be approved")
# Out:
# Please enter the following details:
# Gender (1 for Male, 0 for Female): 1
# Married (1 for Yes, 0 for No): 1
# Dependents: 2
# Education (1 for Graduate, 0 for Not Graduate): 1
# Self Employed (1 for Yes, 0 for No): 1
# Credit History (e.g., 1.0): 1.0
# Property Area (0 for Urban, 1 for Rural, 2 for Semiurban): 0
# Applicant Income log: 5.6
# Loan Amount log: 0
# Loan Amount Term log: 8.4
# Total Income log: 6.7
# Loan will be approved
